# %%
import numpy as np
import matplotlib.pyplot as plt

class WTA:
    def winner(self, weights, sample):
        distances = np.linalg.norm(sample - weights, axis=1)
        print("  Distances:", distances)
        winner_index = np.argmin(distances)
        print("  Winner (WTA):", winner_index)
        return winner_index

    def update_wta(self, weights, sample, winner, alpha):
        weights[winner] += alpha * (sample - weights[winner])
        return weights

def main():
    np.random.seed(42)
    X1 = np.random.randn(50, 2) + np.array([2, 2])
    X2 = np.random.randn(50, 2) + np.array([8, 3])
    X3 = np.random.randn(50, 2) + np.array([3, 7])
    X = np.vstack((X1, X2, X3))
   
    n_clusters = 3
    alpha = 0.5
    epochs = 2
    # Initialize cluster centroids randomly
    weights = np.random.rand(n_clusters, 2)
   
    ob = WTA()
    print("Initial Weights:\n", weights, "\n")
   
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}")
        for idx, sample in enumerate(X):
            winner = ob.winner(weights, sample)
            weights = ob.update_wta(weights, sample, winner, alpha)
            print(f" Sample {idx + 1}: {sample} -> Winner Neuron: {winner}")
            print(f"  Updated Weights:\n{weights}\n")
        alpha *= 0.9
        print(f" Learning Rate after epoch {epoch + 1}: {alpha}\n")
   
    # Assign clusters to each sample
    clusters = []
    for sample in X:
        winner = ob.winner(weights, sample)
        clusters.append(winner)
    clusters = np.array(clusters)
   
    # Visualization
    colors = ['r', 'g', 'b']
    for i in range(n_clusters):
        plt.scatter(X[clusters == i, 0], X[clusters == i, 1], c=colors[i], label=f'Cluster {i}')
    plt.scatter(weights[:,0], weights[:,1], c='k', marker='x', s=100, label='Centroids')
    plt.title("2D Data Clustering using WTA Network")
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Initial Weights:
#  [[0.28203457 0.17743954]
#  [0.75061475 0.80683474]
#  [0.99050514 0.41261768]]
#
# Epoch 1
#   Distances: [2.78238372 2.0400194  2.09012168]
#   Winner (WTA): 1
#  Sample 1: [2.49671415 1.8617357 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [1.62366445 1.33428522]
#  [0.99050514 0.41261768]]
#
#   Distances: [4.09747401 2.41644955 3.52433267]
#   Winner (WTA): 1
#  Sample 2: [2.64768854 3.52302986] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [2.1356765  2.42865754]
#  [0.99050514 0.41261768]]
#
#   Distances: [2.17365761 0.7589932  1.55962413]
#   Winner (WTA): 1
#  Sample 3: [1.76584663 1.76586304] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [1.95076156 2.09726029]
#  [0.99050514 0.41261768]]
#
#   Distances: [4.19278659 1.76096203 3.49951008]
#   Winner (WTA): 1
#  Sample 4: [3.57921282 2.76743473] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [2.76498719 2.43234751]
#  [0.99050514 0.41261768]]
#
#   Distances: [2.67442047 1.23937169 2.19733397]
#   Winner (WTA): 1
#  Sample 5: [1.53052561 2.54256004] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [2.1477564  2.48745378]
#  [0.99050514 0.41261768]]
#
#   Distances: [1.84793928 1.13229529 1.24751944]
#   Winner (WTA): 1
#  Sample 6: [1.53658231 1.53427025] -> Winner Neuron: 1
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [1.84216935 2.01086201]
#  [0.99050514 0.41261768]]
#
#   Distances: [1.96202616 1.96523734 1.29319542]
#   Winner (WTA): 2
#  Sample 7: [2.24196227 0.08671976] -> Winner Neuron: 2
#   Updated Weights:
# [[0.28203457 0.17743954]
#  [1.84216935 2.01086201]
#  [1.61623371 0.24966872]]
#
#   Distances: [1.2602921  1.66861099 1.79168508]
#   Winner (WTA): 0
#  Sample 8: [0.27508217 1.43771247] -> Winner Neuron: 0
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.84216935 2.01086201]
#  [1.61623371 0.24966872]]
#
#   Distances: [1.66498869 0.90723121 2.15828808]
#   Winner (WTA): 1
#  Sample 9: [0.98716888 2.31424733] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.41466912 2.16255467]
#  [1.61623371 0.24966872]]
#
#   Distances: [0.84261213 1.60757886 0.62378592]
#   Winner (WTA): 2
#  Sample 10: [1.09197592 0.5876963 ] -> Winner Neuron: 2
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.41466912 2.16255467]
#  [1.35410482 0.41868251]]
#
#   Distances: [3.33045837 2.08741909 2.50920501]
#   Winner (WTA): 1
#  Sample 11: [3.46564877 1.7742237 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [2.44015894 1.96838919]
#  [1.35410482 0.41868251]]
#
#   Distances: [1.80399213 1.44211144 0.73040186]
#   Winner (WTA): 2
#  Sample 12: [2.0675282  0.57525181] -> Winner Neuron: 2
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [2.44015894 1.96838919]
#  [1.71081651 0.49696716]]
#
#   Distances: [1.75618336 0.99480554 1.63400697]
#   Winner (WTA): 1
#  Sample 13: [1.45561728 2.11092259] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.94788811 2.03965589]
#  [1.71081651 0.49696716]]
#
#   Distances: [1.66865743 1.149115   2.06696547]
#   Winner (WTA): 1
#  Sample 14: [0.84900642 2.37569802] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39844727 2.20767695]
#  [1.71081651 0.49696716]]
#
#   Distances: [1.43788532 0.49937154 1.25073847]
#   Winner (WTA): 1
#  Sample 15: [1.39936131 1.70830625] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39890429 1.9579916 ]
#  [1.71081651 0.49696716]]
#
#   Distances: [3.24407427 1.89428668 3.36983423]
#   Winner (WTA): 1
#  Sample 16: [1.39829339 3.85227818] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39859884 2.90513489]
#  [1.71081651 0.49696716]]
#
#   Distances: [1.71324887 2.04899848 0.52375044]
#   Winner (WTA): 2
#  Sample 17: [1.98650278 0.94228907] -> Winner Neuron: 2
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39859884 2.90513489]
#  [1.84865964 0.71962812]]
#
#   Distances: [2.54414528 2.55879018 0.97570289]
#   Winner (WTA): 2
#  Sample 18: [2.82254491 0.77915635] -> Winner Neuron: 2
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39859884 2.90513489]
#  [2.33560228 0.74939223]]
#
#   Distances: [2.0771964  2.97718605 0.72030002]
#   Winner (WTA): 2
#  Sample 19: [2.2088636  0.04032988] -> Winner Neuron: 2
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.39859884 2.90513489]
#  [2.27223294 0.39486105]]
#
#   Distances: [1.44387098 1.01482405 2.41009244]
#   Winner (WTA): 1
#  Sample 20: [0.67181395 2.19686124] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.03520639 2.55099806]
#  [2.27223294 0.39486105]]
#
#   Distances: [2.81266382 1.74505416 1.83666865]
#   Winner (WTA): 1
#  Sample 21: [2.73846658 2.17136828] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.88683649 2.36118317]
#  [2.27223294 0.39486105]]
#
#   Distances: [1.83657947 0.66229153 1.36049982]
#   Winner (WTA): 1
#  Sample 22: [1.88435172 1.6988963 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.27855837 0.80757601]
#  [1.8855941  2.03003974]
#  [2.27223294 0.39486105]]
#
#   Distances: [0.53135826 1.55664339 1.96185871]
#   Winner (WTA): 0
#  Sample 23: [0.52147801 1.28015579] -> Winner Neuron: 0
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [1.8855941  2.03003974]
#  [2.27223294 0.39486105]]
#
#   Distances: [2.31328848 1.08387067 2.76129236]
#   Winner (WTA): 1
#  Sample 24: [1.53936123 3.05712223] -> Winner Neuron: 1
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [1.71247767 2.54358098]
#  [2.27223294 0.39486105]]
#
#   Distances: [2.10444262 2.39140953 0.1732878 ]
#   Winner (WTA): 2
#  Sample 25: [2.34361829 0.23695984] -> Winner Neuron: 2
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [1.71247767 2.54358098]
#  [2.30792561 0.31591045]]
#
#   Distances: [2.00702001 1.1119702  1.29910776]
#   Winner (WTA): 1
#  Sample 26: [2.32408397 1.61491772] -> Winner Neuron: 1
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [2.01828082 2.07924935]
#  [2.30792561 0.31591045]]
#
#   Distances: [1.81935946 0.87566284 2.49809239]
#   Winner (WTA): 1
#  Sample 27: [1.323078   2.61167629] -> Winner Neuron: 1
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [1.67067941 2.34546282]
#  [2.30792561 0.31591045]]
#
#   Distances: [3.23796158 1.48109848 2.71348381]
#   Winner (WTA): 1
#  Sample 28: [3.03099952 2.93128012] -> Winner Neuron: 1
#   Updated Weights:
# [[0.40001819 1.0438659 ]
#  [2.35083947 2.63837147]
#  [2.30792561 0.31591045]]
#
#   Distances: [0.99863408 1.52123331 1.79059337]
#   Winner (WTA): 0
#  Sample 29: [1.16078248 1.69078762] -> Winner Neuron: 0
#   Updated Weights:
# [[0.78040033 1.36732676]
#  [2.35083947 2.63837147]
#  [2.30792561 0.31591045]]
#
#   Distances: [2.23417606 0.33774146 2.65973707]
#   Winner (WTA): 1
#  Sample 30: [2.33126343 2.97554513] -> Winner Neuron: 1
#   Updated Weights:
# [[0.78040033 1.36732676]
#  [2.34105145 2.8069583 ]
#  [2.30792561 0.31591045]]
#
#   Distances: [0.86489974 1.28765649 1.69257802]
#   Winner (WTA): 0
#  Sample 31: [1.52082576 1.81434102] -> Winner Neuron: 0
#   Updated Weights:
# [[1.15061305 1.59083389]
#  [2.34105145 2.8069583 ]
#  [2.30792561 0.31591045]]
#
#   Distances: [0.82792213 2.47135533 1.49604905]
#   Winner (WTA): 0
#  Sample 32: [0.89366503 0.80379338] -> Winner Neuron: 0
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.34105145 2.8069583 ]
#  [2.30792561 0.31591045]]
#
#   Distances: [2.80471888 0.72387741 3.0819191 ]
#   Winner (WTA): 1
#  Sample 33: [2.81252582 3.35624003] -> Winner Neuron: 1
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.57678864 3.08159916]
#  [2.30792561 0.31591045]]
#
#   Distances: [2.02064192 0.65347851 2.71434441]
#   Winner (WTA): 1
#  Sample 34: [1.92798988 3.0035329 ] -> Winner Neuron: 1
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.25238926 3.04256603]
#  [2.30792561 0.31591045]]
#
#   Distances: [1.34873252 1.69121795 1.04035717]
#   Winner (WTA): 2
#  Sample 35: [2.36163603 1.35488025] -> Winner Neuron: 2
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.25238926 3.04256603]
#  [2.33478082 0.83539535]]
#
#   Distances: [2.69677437 0.50731986 2.70277226]
#   Winner (WTA): 1
#  Sample 36: [2.36139561 3.53803657] -> Winner Neuron: 1
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.30689243 3.2903013 ]
#  [2.33478082 0.83539535]]
#
#   Distances: [2.54787779 0.4389985  2.75429588]
#   Winner (WTA): 1
#  Sample 37: [1.96417396 3.56464366] -> Winner Neuron: 1
#   Updated Weights:
# [[1.02213904 1.19731363]
#  [2.1355332  3.42747248]
#  [2.33478082 0.83539535]]
#
#   Distances: [2.30977759 2.82104121 3.56025759]
#   Winner (WTA): 0
#  Sample 38: [-0.6197451  2.8219025] -> Winner Neuron: 0
#   Updated Weights:
# [[0.20119697 2.00960807]
#  [2.1355332  3.42747248]
#  [2.33478082 0.83539535]]
#
#   Distances: [1.9109354  1.72716053 0.90035032]
#   Winner (WTA): 2
#  Sample 39: [2.08704707 1.70099265] -> Winner Neuron: 2
#   Updated Weights:
# [[0.20119697 2.00960807]
#  [2.1355332  3.42747248]
#  [2.21091394 1.268194  ]]
#
#   Distances: [2.75008135 3.41532191 1.26140318]
#   Winner (WTA): 2
#  Sample 40: [2.09176078 0.01243109] -> Winner Neuron: 2
#   Updated Weights:
# [[0.20119697 2.00960807]
#  [2.1355332  3.42747248]
#  [2.15133736 0.64031254]]
#
#   Distances: [1.61691514 1.12775927 1.7564311 ]
#   Winner (WTA): 1
#  Sample 41: [1.78032811 2.35711257] -> Winner Neuron: 1
#   Updated Weights:
# [[0.20119697 2.00960807]
#  [1.95793065 2.89229252]
#  [2.15133736 0.64031254]]
#
#   Distances: [3.3189455  2.07363834 1.5709028 ]
#   Winner (WTA): 2
#  Sample 42: [3.47789404 1.48172978] -> Winner Neuron: 2
#   Updated Weights:
# [[0.20119697 2.00960807]
#  [1.95793065 2.89229252]
#  [2.8146157  1.06102116]]
#
#   Distances: [1.11454343 1.59084265 1.68096601]
#   Winner (WTA): 0
#  Sample 43: [1.1915064  1.49824296] -> Winner Neuron: 0
#   Updated Weights:
# [[0.69635168 1.75392551]
#  [1.95793065 2.89229252]
#  [2.8146157  1.06102116]]
#
#   Distances: [2.29229346 1.11100429 1.27172997]
#   Winner (WTA): 1
#  Sample 44: [2.91540212 2.32875111] -> Winner Neuron: 1
#   Updated Weights:
# [[0.69635168 1.75392551]
#  [2.43666639 2.61052182]
#  [2.8146157  1.06102116]]
#
#   Distances: [1.08420615 0.97130776 1.978981  ]
#   Winner (WTA): 1
#  Sample 45: [1.4702398  2.51326743] -> Winner Neuron: 1
#   Updated Weights:
# [[0.69635168 1.75392551]
#  [1.95345309 2.56189463]
#  [2.8146157  1.06102116]]
#
#   Distances: [1.85407022 0.43136278 2.03810934]
#   Winner (WTA): 1
#  Sample 46: [2.09707755 2.96864499] -> Winner Neuron: 1
#   Updated Weights:
# [[0.69635168 1.75392551]
#  [2.02526532 2.76526981]
#  [2.8146157  1.06102116]]
#
#   Distances: [0.60710243 1.31281847 1.63523464]
#   Winner (WTA): 0
#  Sample 47: [1.29794691 1.67233785] -> Winner Neuron: 0
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [2.02526532 2.76526981]
#  [2.8146157  1.06102116]]
#
#   Distances: [1.32570878 2.26752775 1.31579656]
#   Winner (WTA): 2
#  Sample 48: [1.60789185 0.53648505] -> Winner Neuron: 2
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [2.02526532 2.76526981]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.40980349 0.5723589  1.46476276]
#   Winner (WTA): 1
#  Sample 49: [2.29612028 2.26105527] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [2.1606928  2.51316254]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.00931911 0.76376338 0.98839512]
#   Winner (WTA): 1
#  Sample 50: [2.00511346 1.76541287] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [2.08290313 2.1392877 ]
#  [2.21125377 0.79875311]]
#
#   Distances: [5.65422626 4.5231844  4.72196517]
#   Winner (WTA): 1
#  Sample 51: [6.58462926 2.57935468] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [4.33376619 2.35932119]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.67774232 3.32744565 5.62284424]
#   Winner (WTA): 1
#  Sample 52: [7.65728548 2.19772273] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [5.99552584 2.27852196]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.04742643 2.1596664  6.20128117]
#   Winner (WTA): 1
#  Sample 53: [7.83871429 3.40405086] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [6.91712006 2.84128641]
#  [2.21125377 0.79875311]]
#
#   Distances: [9.00837369 2.98771403 8.03424708]
#   Winner (WTA): 1
#  Sample 54: [9.8861859  3.17457781] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.40165298 3.00793211]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.36093691 0.16598704 6.409445  ]
#   Winner (WTA): 1
#  Sample 55: [8.25755039 2.92555408] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.32960169 2.9667431 ]
#  [2.21125377 0.79875311]]
#
#   Distances: [5.23797266 2.24838301 4.43916324]
#   Winner (WTA): 1
#  Sample 56: [6.08122878 2.97348612] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.20541524 2.97011461]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.99690192 2.63560114 7.48117524]
#   Winner (WTA): 1
#  Sample 57: [8.06023021 5.46324211] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.63282272 4.21667836]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.99327068 0.93167887 6.13053888]
#   Winner (WTA): 1
#  Sample 58: [7.80763904 3.30154734] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.72023088 3.75911285]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.96914121 1.9433041  5.84594825]
#   Winner (WTA): 1
#  Sample 59: [7.96528823 1.83132196] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.84275955 2.79521741]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.39694635 1.61414661 7.53444895]
#   Winner (WTA): 1
#  Sample 60: [9.14282281 3.75193303] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.49279118 3.27357522]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.80301856 1.21997879 6.70539944]
#   Winner (WTA): 1
#  Sample 61: [8.79103195 2.09061255] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.64191157 2.68209388]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.40643142 1.32434104 7.23583368]
#   Winner (WTA): 1
#  Sample 62: [9.40279431 1.59814894] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [9.02235294 2.14012141]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.34837986 3.08126524 7.74179364]
#   Winner (WTA): 1
#  Sample 63: [8.58685709 5.19045563] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.80460502 3.66528852]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.0553403  2.17700186 5.06911008]
#   Winner (WTA): 1
#  Sample 64: [7.00946367 2.43370227] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.90703435 3.04949539]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.14557484 0.58555811 6.12826675]
#   Winner (WTA): 1
#  Sample 65: [8.09965137 2.49652435] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.00334286 2.77300987]
#  [2.21125377 0.79875311]]
#
#   Distances: [5.61814383 1.58186193 4.80763794]
#   Winner (WTA): 1
#  Sample 66: [6.44933657 3.06856297] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.22633971 2.92078642]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.1959116 0.6236261 5.4308401]
#   Winner (WTA): 1
#  Sample 67: [6.93769629 3.47359243] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.082018   3.19718943]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.71234142 1.35274575 6.1466786 ]
#   Winner (WTA): 1
#  Sample 68: [7.08057577 4.54993441] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.08129688 3.87356192]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.29398476 1.20327139 5.34661549]
#   Winner (WTA): 1
#  Sample 69: [7.21674671 2.67793848] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.1490218  3.2757502 ]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.81656855 2.24509071 6.67319451]
#   Winner (WTA): 1
#  Sample 70: [8.81351722 1.76913568] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.98126951 2.52244294]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.68155488 1.80160016 6.96444789]
#   Winner (WTA): 1
#  Sample 71: [8.22745993 4.30714275] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.10436472 3.41479285]
#  [2.21125377 0.79875311]]
#
#   Distances: [5.59243317 1.72725116 4.81408217]
#   Winner (WTA): 1
#  Sample 72: [6.39251677 3.18463386] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.24844074 3.29971335]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.55160785 1.12046625 6.74422851]
#   Winner (WTA): 1
#  Sample 73: [8.25988279 3.78182287] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.75416177 3.54076811]
#  [2.21125377 0.79875311]]
#
#   Distances: [5.76599783 2.10866342 4.63623057]
#   Winner (WTA): 1
#  Sample 74: [6.76304929 1.67954339] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.25860553 2.61015575]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.68967418 1.43796798 6.7871895 ]
#   Winner (WTA): 1
#  Sample 75: [8.52194157 3.29698467] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.89027355 2.95357021]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.43496574 0.5330207  6.55462882]
#   Winner (WTA): 1
#  Sample 76: [8.25049285 3.34644821] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.0703832  3.15000921]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.50275789 0.75490145 5.65870661]
#   Winner (WTA): 1
#  Sample 77: [7.31997528 3.2322537 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.69517924 3.19113145]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.31835163 1.08506938 6.26094057]
#   Winner (WTA): 1
#  Sample 78: [8.29307247 2.28564858] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.99412586 2.73839002]
#  [2.21125377 0.79875311]]
#
#   Distances: [9.04171345 2.01095623 8.10849799]
#   Winner (WTA): 1
#  Sample 79: [9.86577451 3.47383292] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.92995018 3.10611147]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.12788461 2.19150718 5.41327104]
#   Winner (WTA): 1
#  Sample 80: [6.8086965  3.65655361] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.86932334 3.38133254]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.37495903 0.93647168 5.66615766]
#   Winner (WTA): 1
#  Sample 81: [7.02531833 3.7870846 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.44732084 3.58420857]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.17474983 2.21408664 7.08318549]
#   Winner (WTA): 1
#  Sample 82: [9.15859558 2.17931768] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.30295821 2.88176313]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.145525   0.84742654 7.24046254]
#   Winner (WTA): 1
#  Sample 83: [8.96337613 3.41278093] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.63316717 3.14727203]
#  [2.21125377 0.79875311]]
#
#   Distances: [8.44777659 1.75968865 7.77796194]
#   Winner (WTA): 1
#  Sample 84: [8.82206016 4.89679298] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.72761366 4.0220325 ]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.77846078 2.02486711 5.72923262]
#   Winner (WTA): 1
#  Sample 85: [7.75461188 2.24626384] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.24111277 3.13414817]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.13145791 1.47673252 5.09135608]
#   Winner (WTA): 1
#  Sample 86: [7.11048557 2.18418972] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.67579917 2.65916894]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.11452382 0.72536807 6.25193371]
#   Winner (WTA): 1
#  Sample 87: [7.92289829 3.34115197] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.79934873 3.00016046]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.58029937 0.95489379 6.77944802]
#   Winner (WTA): 1
#  Sample 88: [8.2766908  3.82718325] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.03801977 3.41367185]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.53206432 1.04016313 6.85694576]
#   Winner (WTA): 1
#  Sample 89: [8.01300189 4.45353408] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.02551083 3.93360297]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.83961772 1.80997681 7.39837142]
#   Winner (WTA): 1
#  Sample 90: [7.73534317 5.72016917] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.880427   4.82688607]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.64061117 2.78558313 6.55372243]
#   Winner (WTA): 1
#  Sample 91: [8.62566735 2.14284244] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.25304717 3.48486425]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.19020959 1.32394183 5.42775212]
#   Winner (WTA): 1
#  Sample 92: [6.9291075  3.48247242] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.59107734 3.48366834]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.06849182 0.29571654 6.28259875]
#   Winner (WTA): 1
#  Sample 93: [7.77653721 3.71400049] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.68380728 3.59883441]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.57402062 1.03649983 6.61381923]
#   Winner (WTA): 1
#  Sample 94: [8.47323762 2.92717109] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.07852245 3.26300275]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.16027694 2.00423565 4.98939266]
#   Winner (WTA): 1
#  Sample 95: [7.15320628 1.48515278] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.61586437 2.37407776]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.89776286 1.48363298 6.15537425]
#   Winner (WTA): 1
#  Sample 96: [7.55348505 3.85639879] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.58467471 3.11523828]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.21706165 1.49947553 6.07841126]
#   Winner (WTA): 1
#  Sample 97: [8.21409374 1.75426122] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.89938423 2.43474975]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.36828576 0.98921355 6.4988376 ]
#   Winner (WTA): 1
#  Sample 98: [8.17318093 3.38531738] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [8.03628258 2.91003356]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.28628571 0.95186302 5.44093991]
#   Winner (WTA): 1
#  Sample 99: [7.11614256 3.15372511] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.57621257 3.03187934]
#  [2.21125377 0.79875311]]
#
#   Distances: [7.06252553 1.26987871 5.94195519]
#   Winner (WTA): 1
#  Sample 100: [8.05820872 1.8570297 ] -> Winner Neuron: 1
#   Updated Weights:
# [[0.99714929 1.71313168]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [6.30616015 6.78699409 6.85854272]
#   Winner (WTA): 0
#  Sample 101: [3.35778736 7.56078453] -> Winner Neuron: 0
#   Updated Weights:
# [[2.17746833 4.6369581 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [3.91229713 6.73859972 7.49262043]
#   Winner (WTA): 0
#  Sample 102: [4.08305124 8.05380205] -> Winner Neuron: 0
#   Updated Weights:
# [[3.13025979 6.34538008]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.53429315 7.17387201 5.29626662]
#   Winner (WTA): 0
#  Sample 103: [1.62233063 6.06217496] -> Winner Neuron: 0
#   Updated Weights:
# [[2.37629521 6.20377752]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.73575661 6.64882201 6.84043217]
#   Winner (WTA): 0
#  Sample 104: [3.51503527 7.51378595] -> Winner Neuron: 0
#   Updated Weights:
# [[2.94566524 6.85878174]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [ 4.03433155  9.44498426 10.13816354]
#   Winner (WTA): 0
#  Sample 105: [ 3.51504769 10.85273149] -> Winner Neuron: 0
#   Updated Weights:
# [[3.23035646 8.85575661]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.796642   7.10070282 7.46173105]
#   Winner (WTA): 0
#  Sample 106: [3.57089051 8.13556564] -> Winner Neuron: 0
#   Updated Weights:
# [[3.40062349 8.49566113]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.00946478 6.48356175 7.07077224]
#   Winner (WTA): 0
#  Sample 107: [3.95400176 7.65139125] -> Winner Neuron: 0
#   Updated Weights:
# [[3.67731262 8.07352619]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.04123237 7.38826206 6.97630194]
#   Winner (WTA): 0
#  Sample 108: [2.68473076 7.75896922] -> Winner Neuron: 0
#   Updated Weights:
# [[3.18102169 7.9162477 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.49645776 7.06398632 5.96444954]
#   Winner (WTA): 0
#  Sample 109: [2.22717479 6.76318139] -> Winner Neuron: 0
#   Updated Weights:
# [[2.70409824 7.33971455]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.31996476 7.04435617 6.29044124]
#   Winner (WTA): 0
#  Sample 110: [2.51463645 7.08187414] -> Winner Neuron: 0
#   Updated Weights:
# [[2.60936734 7.21079434]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [3.41129477 3.67282151 5.33052705]
#   Winner (WTA): 0
#  Sample 111: [5.31465857 5.13273481] -> Winner Neuron: 0
#   Updated Weights:
# [[3.96201296 6.17176458]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.83153422 5.07198164 4.81977809]
#   Winner (WTA): 0
#  Sample 112: [3.68626019 5.38728413] -> Winner Neuron: 0
#   Updated Weights:
# [[3.82413657 5.77952435]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.64825282 7.73533221 7.29707824]
#   Winner (WTA): 0
#  Sample 113: [2.52806813 8.0889506 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.17610235 6.93423747]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.0181416  5.88943522 5.19402808]
#   Winner (WTA): 0
#  Sample 114: [3.06428002 5.92225522] -> Winner Neuron: 0
#   Updated Weights:
# [[3.12019119 6.42824635]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.50463685 7.61678671 6.88123657]
#   Winner (WTA): 0
#  Sample 115: [2.28469629 7.67959775] -> Winner Neuron: 0
#   Updated Weights:
# [[2.70244374 7.05392205]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.46232342 7.31762506 6.41797101]
#   Winner (WTA): 0
#  Sample 116: [2.26963337 7.21645859] -> Winner Neuron: 0
#   Updated Weights:
# [[2.48603855 7.13519032]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.96546209 6.16517027 5.61201064]
#   Winner (WTA): 0
#  Sample 117: [3.04557184 6.34839965] -> Winner Neuron: 0
#   Updated Weights:
# [[2.7658052  6.74179499]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.53996651 5.83754194 7.43775272]
#   Winner (WTA): 0
#  Sample 118: [5.14394409 7.63391902] -> Winner Neuron: 0
#   Updated Weights:
# [[3.95487464 7.187857  ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.98001756 8.32492401 6.50625873]
#   Winner (WTA): 0
#  Sample 119: [0.97485741 7.18645431] -> Winner Neuron: 0
#   Updated Weights:
# [[2.46486603 7.18715566]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.67722614 7.69841829 7.05482271]
#   Winner (WTA): 0
#  Sample 120: [2.33821354 7.85243333] -> Winner Neuron: 0
#   Updated Weights:
# [[2.40153978 7.5197945 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.66354276 7.15470972 6.08651162]
#   Winner (WTA): 0
#  Sample 121: [2.20747926 6.88526356] -> Winner Neuron: 0
#   Updated Weights:
# [[2.30450952 7.20252903]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.37150129 6.92717629 7.18444604]
#   Winner (WTA): 0
#  Sample 122: [3.50498728 7.86575519] -> Winner Neuron: 0
#   Updated Weights:
# [[2.9047484  7.53414211]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.40558361 7.35034731 5.88116299]
#   Winner (WTA): 0
#  Sample 123: [1.79970359 6.66549876] -> Winner Neuron: 0
#   Updated Weights:
# [[2.352226   7.09982044]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.77272517 6.57527234 5.55678517]
#   Winner (WTA): 0
#  Sample 124: [2.52505469 6.34667077] -> Winner Neuron: 0
#   Updated Weights:
# [[2.43864034 6.7232456 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.42462926 5.82409196 7.08280992]
#   Winner (WTA): 0
#  Sample 125: [4.76545424 7.40498171] -> Winner Neuron: 0
#   Updated Weights:
# [[3.60204729 7.06411366]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.04924351 8.179329   7.1347477 ]
#   Winner (WTA): 0
#  Sample 126: [1.73911605 7.91786195] -> Winner Neuron: 0
#   Updated Weights:
# [[2.67058167 7.4909878 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.51066037 6.20396506 7.79743191]
#   Winner (WTA): 0
#  Sample 127: [5.1221562  8.03246526] -> Winner Neuron: 0
#   Updated Weights:
# [[3.89636893 7.76172653]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.71812661 7.531788   5.76350992]
#   Winner (WTA): 0
#  Sample 128: [1.48063003 6.51576593] -> Winner Neuron: 0
#   Updated Weights:
# [[2.68849948 7.13874623]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.79103404 5.23553019 5.8655878 ]
#   Winner (WTA): 0
#  Sample 129: [4.26691115 6.29233053] -> Winner Neuron: 0
#   Updated Weights:
# [[3.47770532 6.71553838]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.05963762 6.89473456 7.08393486]
#   Winner (WTA): 0
#  Sample 130: [3.44381943 7.77463405] -> Winner Neuron: 0
#   Updated Weights:
# [[3.46076237 7.24508622]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.42073208 7.29447422 6.14327586]
#   Winner (WTA): 0
#  Sample 131: [2.07306953 6.94047464] -> Winner Neuron: 0
#   Updated Weights:
# [[2.76691595 7.09278043]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [3.20892992 8.79818976 5.7284144 ]
#   Winner (WTA): 0
#  Sample 132: [-0.24126734  5.97561236] -> Winner Neuron: 0
#   Updated Weights:
# [[1.26282431 6.53419639]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.67796055 6.05342452 4.98239798]
#   Winner (WTA): 0
#  Sample 133: [2.74743185 5.75221682] -> Winner Neuron: 0
#   Updated Weights:
# [[2.00512808 6.14320661]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.68911604 4.4621853  5.35027585]
#   Winner (WTA): 0
#  Sample 134: [4.6324113  5.56985862] -> Winner Neuron: 0
#   Updated Weights:
# [[3.31876969 5.85653261]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.48303907 7.04272735 6.34158168]
#   Winner (WTA): 0
#  Sample 135: [2.55995551 7.13074058] -> Winner Neuron: 0
#   Updated Weights:
# [[2.9393626  6.4936366 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.76626828 4.59667022 5.26135712]
#   Winner (WTA): 0
#  Sample 136: [4.44127329 5.56413785] -> Winner Neuron: 0
#   Updated Weights:
# [[3.69031795 6.02888722]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.08932218 5.84793916 6.51094738]
#   Winner (WTA): 0
#  Sample 137: [4.16316375 7.01023306] -> Winner Neuron: 0
#   Updated Weights:
# [[3.92674085 6.51956014]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.12833364 7.66824273 6.66613797]
#   Winner (WTA): 0
#  Sample 138: [2.01849135 7.46210347] -> Winner Neuron: 0
#   Updated Weights:
# [[2.9726161  6.99083181]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.63294174 6.08045578 5.68746849]
#   Winner (WTA): 0
#  Sample 139: [3.1990597  6.39978312] -> Winner Neuron: 0
#   Updated Weights:
# [[3.0858379  6.69530747]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.08220038 6.31891779 5.87896124]
#   Winner (WTA): 0
#  Sample 140: [3.06980208 6.6146864 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.07781999 6.65499693]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.00776618 7.02487545 6.92242957]
#   Winner (WTA): 0
#  Sample 141: [3.11351735 7.66213067] -> Winner Neuron: 0
#   Updated Weights:
# [[3.09566867 7.1585638 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.04230575 4.6311927  5.50228595]
#   Winner (WTA): 0
#  Sample 142: [4.58601682 5.7621845 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.84084274 6.46037415]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.91436815 3.73935817 5.15675761]
#   Winner (WTA): 0
#  Sample 143: [5.13303337 5.0479122 ] -> Winner Neuron: 0
#   Updated Weights:
# [[4.48693806 5.75414318]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [2.45959508 7.15193974 6.81937681]
#   Winner (WTA): 0
#  Sample 144: [2.8482149  7.58831721] -> Winner Neuron: 0
#   Updated Weights:
# [[3.66757648 6.67123019]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.48563601 6.00371203 5.68018753]
#   Winner (WTA): 0
#  Sample 145: [3.28099187 6.37730048] -> Winner Neuron: 0
#   Updated Weights:
# [[3.47428417 6.52426534]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.68262483 6.4620615  5.73769955]
#   Winner (WTA): 0
#  Sample 146: [2.79187775 6.50699907] -> Winner Neuron: 0
#   Updated Weights:
# [[3.13308096 6.5156322 ]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.51703774 7.6450427  7.05366745]
#   Winner (WTA): 0
#  Sample 147: [2.41063524 7.8496021 ] -> Winner Neuron: 0
#   Updated Weights:
# [[2.7718581  7.18261715]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.05306991 5.90027939 5.62623761]
#   Winner (WTA): 0
#  Sample 148: [3.35701549 6.3070904 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.06443679 6.74485378]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [1.00689751 6.24459251 6.72396378]
#   Winner (WTA): 0
#  Sample 149: [3.89959988 7.30729952] -> Winner Neuron: 0
#   Updated Weights:
# [[3.48201833 7.02607665]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#   Distances: [0.68828254 6.55139984 7.01612518]
#   Winner (WTA): 0
#  Sample 150: [3.81286212 7.62962884] -> Winner Neuron: 0
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.21125377 0.79875311]]
#
#  Learning Rate after epoch 1: 0.45
#
# Epoch 2
#   Distances: [5.58592929 5.35231204 1.10064509]
#   Winner (WTA): 2
#  Sample 1: [2.49671415 1.8617357 ] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.33971094 1.27709527]]
#
#   Distances: [3.93397771 5.28084118 2.26695222]
#   Winner (WTA): 2
#  Sample 2: [2.64768854 3.52302986] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.47830086 2.28776584]]
#
#   Distances: [5.87163724 6.0892933  0.88316112]
#   Winner (WTA): 2
#  Sample 3: [1.76584663 1.76586304] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.15769646 2.05290958]]
#
#   Distances: [4.56092836 4.25028726 1.59099181]
#   Winner (WTA): 2
#  Sample 4: [3.57921282 2.76743473] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.79737882 2.3744459 ]]
#
#   Distances: [5.23262398 6.28745047 1.27795908]
#   Winner (WTA): 2
#  Sample 5: [1.53052561 2.54256004] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.22729488 2.45009726]]
#
#   Distances: [6.16614299 6.34623729 1.14709327]
#   Winner (WTA): 2
#  Sample 6: [1.53658231 1.53427025] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.91647422 2.03797511]]
#
#   Distances: [7.37627109 6.05328899 1.97821635]
#   Winner (WTA): 2
#  Sample 7: [2.24196227 0.08671976] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.06294384 1.1599102 ]]
#
#   Distances: [6.78723444 7.60902303 1.80931575]
#   Winner (WTA): 2
#  Sample 8: [0.27508217 1.43771247] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.25840609 1.28492122]]
#
#   Distances: [5.67567466 6.83128278 1.06446318]
#   Winner (WTA): 2
#  Sample 9: [0.98716888 2.31424733] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.13634934 1.74811797]]
#
#   Distances: [7.20833592 6.97684263 1.16126976]
#   Winner (WTA): 2
#  Sample 10: [1.09197592 0.5876963 ] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.11638131 1.22592822]]
#
#   Distances: [5.55660361 4.40287407 2.41240244]
#   Winner (WTA): 2
#  Sample 11: [3.46564877 1.7742237 ] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.17355166 1.47266118]]
#
#   Distances: [6.93496513 6.04588843 0.90365068]
#   Winner (WTA): 2
#  Sample 12: [2.0675282  0.57525181] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.12584111 1.06882697]]
#
#   Distances: [5.65866133 6.37033074 1.23901706]
#   Winner (WTA): 2
#  Sample 13: [1.45561728 2.11092259] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.82424038 1.53777   ]]
#
#   Distances: [5.68815156 6.96854343 1.28577006]
#   Winner (WTA): 2
#  Sample 14: [0.84900642 2.37569802] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.3853851  1.91483761]]
#
#   Distances: [6.05253349 6.45993068 0.20700371]
#   Winner (WTA): 2
#  Sample 15: [1.39936131 1.70830625] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.39167439 1.8218985 ]]
#
#   Distances: [4.13984058 6.57148889 2.03039048]
#   Winner (WTA): 2
#  Sample 16: [1.39829339 3.85227818] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.39465294 2.73556936]]
#
#   Distances: [6.59804036 6.02110084 1.88842273]
#   Winner (WTA): 2
#  Sample 17: [1.98650278 0.94228907] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.66098537 1.92859323]]
#
#   Distances: [6.60044519 5.26496949 1.63414372]
#   Winner (WTA): 2
#  Sample 18: [2.82254491 0.77915635] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.18368716 1.41134663]]
#
#   Distances: [7.42815538 6.10191543 1.3712479 ]
#   Winner (WTA): 2
#  Sample 19: [2.2088636  0.04032988] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.19501656 0.79438909]]
#
#   Distances: [5.93139323 7.14968505 2.07052512]
#   Winner (WTA): 2
#  Sample 20: [0.67181395 2.19686124] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.50957538 1.42550156]]
#
#   Distances: [5.2359875  5.08608075 1.43752939]
#   Winner (WTA): 2
#  Sample 21: [2.73846658 2.17136828] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.06257642 1.76114158]]
#
#   Distances: [5.89861269 5.97952106 0.18878167]
#   Winner (WTA): 2
#  Sample 22: [1.88435172 1.6988963 ] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.98237531 1.73313121]]
#
#   Distances: [6.80781009 7.38805158 1.52951222]
#   Winner (WTA): 2
#  Sample 23: [0.52147801 1.28015579] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.32497152 1.52929227]]
#
#   Distances: [4.76268162 6.30767429 1.54279854]
#   Winner (WTA): 2
#  Sample 24: [1.53936123 3.05712223] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.42144689 2.21681575]]
#
#   Distances: [7.20976517 5.90196967 2.18408551]
#   Winner (WTA): 2
#  Sample 25: [2.34361829 0.23695984] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.83642402 1.32588059]]
#
#   Distances: [5.86420484 5.55540925 0.56688155]
#   Winner (WTA): 2
#  Sample 26: [2.32408397 1.61491772] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.055871   1.4559473 ]]
#
#   Distances: [5.25784938 6.49628524 1.36846449]
#   Winner (WTA): 2
#  Sample 27: [1.323078   2.61167629] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.72611415 1.97602534]]
#
#   Distances: [4.43957768 4.81090595 1.6171696 ]
#   Winner (WTA): 2
#  Sample 28: [3.03099952 2.93128012] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.31331257 2.40588999]]
#
#   Distances: [6.16116628 6.69895885 1.35635431]
#   Winner (WTA): 2
#  Sample 29: [1.16078248 1.69078762] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.79467403 2.08409393]]
#
#   Distances: [4.54696635 5.51159451 1.04048711]
#   Winner (WTA): 2
#  Sample 30: [2.33126343 2.97554513] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.03613926 2.48524697]]
#
#   Distances: [5.90942473 6.32783578 0.84596855]
#   Winner (WTA): 2
#  Sample 31: [1.52082576 1.81434102] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.80424819 2.18333929]]
#
#   Distances: [7.08142842 7.11528305 1.65296964]
#   Winner (WTA): 2
#  Sample 32: [0.89366503 0.80379338] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.39448576 1.56254363]]
#
#   Distances: [4.05842206 5.08706428 2.28652233]
#   Winner (WTA): 2
#  Sample 33: [2.81252582 3.35624003] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.03260379 2.36970701]]
#
#   Distances: [4.65362779 5.91569859 0.64240122]
#   Winner (WTA): 2
#  Sample 34: [1.92798988 3.0035329 ] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.98552753 2.65492866]]
#
#   Distances: [6.10980302 5.56331435 1.35336007]
#   Winner (WTA): 2
#  Sample 35: [2.36163603 1.35488025] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.15477635 2.06990687]]
#
#   Distances: [4.00207664 5.56433639 1.48259783]
#   Winner (WTA): 2
#  Sample 36: [2.36139561 3.53803657] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.24775502 2.73056524]]
#
#   Distances: [4.12251476 5.95926691 0.88096823]
#   Winner (WTA): 2
#  Sample 37: [1.96417396 3.56464366] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.12014354 3.10590052]]
#
#   Distances: [6.20584065 8.44539456 2.75456796]
#   Winner (WTA): 2
#  Sample 38: [-0.6197451  2.8219025] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [0.88719365 2.97810142]]
#
#   Distances: [5.83921068 5.77819264 1.75232846]
#   Winner (WTA): 2
#  Sample 39: [2.08704707 1.70099265] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.42712769 2.40340247]]
#
#   Distances: [7.47900612 6.22057185 2.48162876]
#   Winner (WTA): 2
#  Sample 40: [2.09176078 0.01243109] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.72621258 1.32746535]]
#
#   Distances: [5.30983668 6.03751433 1.03106833]
#   Winner (WTA): 2
#  Sample 41: [1.78032811 2.35711257] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.75056457 1.7908066 ]]
#
#   Distances: [5.84858099 4.4448293  1.75476369]
#   Winner (WTA): 2
#  Sample 42: [3.47789404 1.48172978] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.52786283 1.65172203]]
#
#   Distances: [6.32581704 6.69292709 1.34514101]
#   Winner (WTA): 2
#  Sample 43: [1.1915064  1.49824296] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.92650244 1.58265645]]
#
#   Distances: [5.05241496 4.90317388 1.23878159]
#   Winner (WTA): 2
#  Sample 44: [2.91540212 2.32875111] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.37150729 1.91839905]]
#
#   Distances: [5.28397894 6.34734387 1.07988495]
#   Winner (WTA): 2
#  Sample 45: [1.4702398  2.51326743] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.96593692 2.18608982]]
#
#   Distances: [4.62669609 5.74410117 0.79346737]
#   Winner (WTA): 2
#  Sample 46: [2.09707755 2.96864499] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [2.0249502  2.53823965]]
#
#   Distances: [6.12412994 6.56482778 1.13062802]
#   Winner (WTA): 2
#  Sample 47: [1.29794691 1.67233785] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.69779872 2.14858384]]
#
#   Distances: [7.0910107  6.49584386 1.6146039 ]
#   Winner (WTA): 2
#  Sample 48: [1.60789185 0.53648505] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.65734063 1.42313939]]
#
#   Distances: [5.24390143 5.5241356  1.05363299]
#   Winner (WTA): 2
#  Sample 49: [2.29612028 2.26105527] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.94479147 1.80020153]]
#
#   Distances: [5.7998254  5.8516298  0.06963472]
#   Winner (WTA): 2
#  Sample 50: [2.00511346 1.76541287] -> Winner Neuron: 2
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.81721064 2.44445452]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.58348577 1.2399415  4.68066828]
#   Winner (WTA): 1
#  Sample 51: [6.58462926 2.57935468] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.26254902 2.50515959]
#  [1.97193636 1.78454663]]
#
#   Distances: [6.51130501 0.50033419 5.70034289]
#   Winner (WTA): 1
#  Sample 52: [7.65728548 2.19772273] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.44018043 2.366813  ]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.74134126 1.11116677 6.08620384]
#   Winner (WTA): 1
#  Sample 53: [7.83871429 3.40405086] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.61952067 2.83357004]
#  [1.97193636 1.78454663]]
#
#   Distances: [7.4947742  2.29217312 8.03539249]
#   Winner (WTA): 1
#  Sample 54: [9.8861859  3.17457781] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.63952002 2.98702354]
#  [1.97193636 1.78454663]]
#
#   Distances: [6.37442933 0.38688408 6.38833638]
#   Winner (WTA): 1
#  Sample 55: [8.25755039 2.92555408] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.46763369 2.95936228]
#  [1.97193636 1.78454663]]
#
#   Distances: [4.98837002 2.3864467  4.27783372]
#   Winner (WTA): 1
#  Sample 56: [6.08122878 2.97348612] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.39375148 2.96571801]
#  [1.97193636 1.78454663]]
#
#   Distances: [4.79056241 2.58492176 7.1133763 ]
#   Winner (WTA): 1
#  Sample 57: [8.06023021 5.46324211] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.69366691 4.08960386]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.78950683 0.79625543 6.02965313]
#   Winner (WTA): 1
#  Sample 58: [7.80763904 3.30154734] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.74495437 3.73497843]
#  [1.97193636 1.78454663]]
#
#   Distances: [6.98968254 1.91636503 5.99353439]
#   Winner (WTA): 1
#  Sample 59: [7.96528823 1.83132196] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.8441046  2.87833302]
#  [1.97193636 1.78454663]]
#
#   Distances: [6.55640386 1.56519838 7.43587397]
#   Winner (WTA): 1
#  Sample 60: [9.14282281 3.75193303] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.4285278  3.27145302]
#  [1.97193636 1.78454663]]
#
#   Distances: [7.34065533 1.23523014 6.82596081]
#   Winner (WTA): 1
#  Sample 61: [8.79103195 2.09061255] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.59165467 2.74007481]
#  [1.97193636 1.78454663]]
#
#   Distances: [8.12118257 1.40069348 7.43319541]
#   Winner (WTA): 1
#  Sample 62: [9.40279431 1.59814894] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.95666751 2.22620817]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.38203544 2.9872266  7.44025486]
#   Winner (WTA): 1
#  Sample 63: [8.58685709 5.19045563] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.79025282 3.56011952]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.93766878 2.10713687 5.07918147]
#   Winner (WTA): 1
#  Sample 64: [7.00946367 2.43370227] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.9888977  3.05323176]
#  [1.97193636 1.78454663]]
#
#   Distances: [6.56992528 0.5676174  6.1689386 ]
#   Winner (WTA): 1
#  Sample 65: [8.09965137 2.49652435] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [8.03873685 2.80271342]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.0982519  1.61148045 4.65787619]
#   Winner (WTA): 1
#  Sample 66: [6.44933657 3.06856297] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.32350672 2.92234572]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.06765306 0.67284666 5.24515465]
#   Winner (WTA): 1
#  Sample 67: [6.93769629 3.47359243] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.14989203 3.17040674]
#  [1.97193636 1.78454663]]
#
#   Distances: [4.4162484  1.38126801 5.80909339]
#   Winner (WTA): 1
#  Sample 68: [7.08057577 4.54993441] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.11869971 3.79119419]
#  [1.97193636 1.78454663]]
#
#   Distances: [5.86188122 1.11756498 5.32035568]
#   Winner (WTA): 1
#  Sample 69: [7.21674671 2.67793848] -> Winner Neuron: 1
#   Updated Weights:
# [[3.64744023 7.32785275]
#  [7.16282086 3.29022912]
#  [1.97193636 1.78454663]]
#
#   Distances: [7.58865514 2.24466561 6.84159821]
#   Winner (WTA): 1
# ...
#   Updated Weights:
# [[2.38613453 7.12737952]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.79297224 6.54190846 4.59553223]
#   Winner (WTA): 0
#  Sample 124: [2.52505469 6.34667077] -> Winner Neuron: 0
#   Updated Weights:
# [[2.4486486  6.77606058]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.40065203 5.78013677 6.27638691]
#   Winner (WTA): 0
#  Sample 125: [4.76545424 7.40498171] -> Winner Neuron: 0
#   Updated Weights:
# [[3.49121114 7.05907509]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.95124373 8.14271428 6.13773265]
#   Winner (WTA): 0
#  Sample 126: [1.73911605 7.91786195] -> Winner Neuron: 0
#   Updated Weights:
# [[2.70276835 7.44552918]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.48956453 6.15822847 6.99716887]
#   Winner (WTA): 0
#  Sample 127: [5.1221562  8.03246526] -> Winner Neuron: 0
#   Updated Weights:
# [[3.79149288 7.70965041]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.60104734 7.50071508 4.75666037]
#   Winner (WTA): 0
#  Sample 128: [1.48063003 6.51576593] -> Winner Neuron: 0
#   Updated Weights:
# [[2.7516046  7.17240239]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.7523357  5.19620488 5.05836189]
#   Winner (WTA): 0
#  Sample 129: [4.26691115 6.29233053] -> Winner Neuron: 0
#   Updated Weights:
# [[3.43349255 6.77637006]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.99831741 6.85384245 6.16827261]
#   Winner (WTA): 0
#  Sample 130: [3.44381943 7.77463405] -> Winner Neuron: 0
#   Updated Weights:
# [[3.43813964 7.22558886]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.39452735 7.26011522 5.15691977]
#   Winner (WTA): 0
#  Sample 131: [2.07306953 6.94047464] -> Winner Neuron: 0
#   Updated Weights:
# [[2.82385809 7.09728746]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [3.2639162  8.77329047 4.73954666]
#   Winner (WTA): 0
#  Sample 132: [-0.24126734  5.97561236] -> Winner Neuron: 0
#   Updated Weights:
# [[1.44455165 6.59253366]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.55036422 6.0221161  4.04274658]
#   Winner (WTA): 0
#  Sample 133: [2.74743185 5.75221682] -> Winner Neuron: 0
#   Updated Weights:
# [[2.03084774 6.21439108]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.68021549 4.42430613 4.626739  ]
#   Winner (WTA): 0
#  Sample 134: [4.6324113  5.56985862] -> Winner Neuron: 0
#   Updated Weights:
# [[3.20155134 5.92435148]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.36638936 7.00628142 5.37843436]
#   Winner (WTA): 0
#  Sample 135: [2.55995551 7.13074058] -> Winner Neuron: 0
#   Updated Weights:
# [[2.91283322 6.46722657]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.77530231 4.55970084 4.51474635]
#   Winner (WTA): 0
#  Sample 136: [4.44127329 5.56413785] -> Winner Neuron: 0
#   Updated Weights:
# [[3.60063125 6.06083665]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.10353811 5.80674767 5.66650475]
#   Winner (WTA): 0
#  Sample 137: [4.16316375 7.01023306] -> Winner Neuron: 0
#   Updated Weights:
# [[3.85377088 6.48806503]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.0777396  7.63225936 5.67774771]
#   Winner (WTA): 0
#  Sample 138: [2.01849135 7.46210347] -> Winner Neuron: 0
#   Updated Weights:
# [[3.02789509 6.92638233]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.55371838 6.04465319 4.77558787]
#   Winner (WTA): 0
#  Sample 139: [3.1990597  6.39978312] -> Winner Neuron: 0
#   Updated Weights:
# [[3.10491916 6.68941269]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.0825665  6.28271052 4.9533382 ]
#   Winner (WTA): 0
#  Sample 140: [3.06980208 6.6146864 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.08911648 6.65578586]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.0066406  6.98521228 5.98742025]
#   Winner (WTA): 0
#  Sample 141: [3.11351735 7.66213067] -> Winner Neuron: 0
#   Updated Weights:
# [[3.10009687 7.10864103]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.00521901 4.59264464 4.75972894]
#   Winner (WTA): 0
#  Sample 142: [4.58601682 5.7621845 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.76876084 6.50273559]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.9944299  3.70167394 4.54335659]
#   Winner (WTA): 0
#  Sample 143: [5.13303337 5.0479122 ] -> Winner Neuron: 0
#   Updated Weights:
# [[4.38268348 5.84806506]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [2.32014468 7.11324242 5.86954998]
#   Winner (WTA): 0
#  Sample 144: [2.8482149  7.58831721] -> Winner Neuron: 0
#   Updated Weights:
# [[3.69217262 6.63117853]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.48324288 5.96771639 4.77566898]
#   Winner (WTA): 0
#  Sample 145: [3.28099187 6.37730048] -> Winner Neuron: 0
#   Updated Weights:
# [[3.50714128 6.51693341]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.71533252 6.42718451 4.79310555]
#   Winner (WTA): 0
#  Sample 146: [2.79187775 6.50699907] -> Winner Neuron: 0
#   Updated Weights:
# [[3.18527269 6.51246295]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [1.54531688 7.60684778 6.08090079]
#   Winner (WTA): 0
#  Sample 147: [2.41063524 7.8496021 ] -> Winner Neuron: 0
#   Updated Weights:
# [[2.83668584 7.11417557]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.96027569 5.86430291 4.72988862]
#   Winner (WTA): 0
#  Sample 148: [3.35701549 6.3070904 ] -> Winner Neuron: 0
#   Updated Weights:
# [[3.07083418 6.75098724]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.99816628 6.20347855 5.84950306]
#   Winner (WTA): 0
#  Sample 149: [3.89959988 7.30729952] -> Winner Neuron: 0
#   Updated Weights:
# [[3.44377874 7.00132777]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#   Distances: [0.72868702 6.50977569 6.12813133]
#   Winner (WTA): 0
#  Sample 150: [3.81286212 7.62962884] -> Winner Neuron: 0
#   Updated Weights:
# [[3.60986626 7.28406325]
#  [7.81083169 2.49217628]
#  [1.97193636 1.78454663]]
#
#  Learning Rate after epoch 2: 0.405
#
#   Distances: [5.53540818 5.35138305 0.53042425]
#   Winner (WTA): 2
#   Distances: [3.88215896 5.26504571 1.86519836]
#   Winner (WTA): 2
#   Distances: [5.81815623 6.08846248 0.20693491]
#   Winner (WTA): 2
#   Distances: [4.51673254 4.24056194 1.88398689]
#   Winner (WTA): 2
#   Distances: [5.17740381 6.28050818 0.87717033]
#   Winner (WTA): 2
#   Distances: [6.11217032 6.34695118 0.50216673]
#   Winner (WTA): 2
#   Distances: [7.32618009 6.066179   1.71916552]
#   Winner (WTA): 2
#   Distances: [6.73057222 7.6091665  1.73193767]
#   Winner (WTA): 2
#   Distances: [5.61939604 6.82598219 1.11819043]
#   Winner (WTA): 2
#   Distances: [7.15409688 6.98355689 1.48552385]
#   Winner (WTA): 2
#   Distances: [5.51172664 4.40409702 1.49374808]
#   Winner (WTA): 2
#   Distances: [6.88381853 6.0547613  1.21306709]
#   Winner (WTA): 2
#   Distances: [5.60376418 6.36663998 0.61082458]
#   Winner (WTA): 2
#   Distances: [5.63155363 6.9627996  1.26902782]
#   Winner (WTA): 2
#   Distances: [5.99794951 6.45921084 0.57762859]
#   Winner (WTA): 2
#   Distances: [4.0826711  6.55519067 2.14582852]
#   Winner (WTA): 2
#   Distances: [6.54625151 6.02701897 0.84238351]
#   Winner (WTA): 2
#   Distances: [6.55238038 5.27422433 1.31694515]
#   Winner (WTA): 2
#   Distances: [7.37797274 6.11503044 1.76023482]
#   Winner (WTA): 2
#   Distances: [5.87467239 7.14512318 1.36393608]
#   Winner (WTA): 2
#   Distances: [5.18642336 5.08249994 0.85860326]
#   Winner (WTA): 2
#   Distances: [5.84563857 5.97933592 0.12250326]
#   Winner (WTA): 2
#   Distances: [6.75166993 7.38942966 1.53565607]
#   Winner (WTA): 2
#   Distances: [4.70680587 6.29686475 1.34408701]
#   Winner (WTA): 2
#   Distances: [7.15996162 5.91408687 1.59159427]
#   Winner (WTA): 2
#   Distances: [5.81312714 5.55643619 0.39087326]
#   Winner (WTA): 2
#   Distances: [5.20198044 6.48885415 1.05126621]
#   Winner (WTA): 2
#   Distances: [4.39110552 4.79995914 1.56096523]
#   Winner (WTA): 2
#   Distances: [6.10595968 6.69816231 0.81655458]
#   Winner (WTA): 2
#   Distances: [4.4942356  5.50084664 1.24402305]
#   Winner (WTA): 2
#   Distances: [5.85507912 6.32642357 0.45209344]
#   Winner (WTA): 2
#   Distances: [7.02649606 7.12024097 1.45758226]
#   Winner (WTA): 2
#   Distances: [4.00793551 5.07244199 1.78236101]
#   Winner (WTA): 2
#   Distances: [4.59909211 5.90502442 1.21977818]
#   Winner (WTA): 2
#   Distances: [6.05914927 5.56661259 0.58006813]
#   Winner (WTA): 2
#   Distances: [3.94859404 5.54888974 1.79621977]
#   Winner (WTA): 2
#   Distances: [4.06723312 5.94420667 1.78011395]
#   Winner (WTA): 2
#   Distances: [6.14821038 8.43702225 2.7915802 ]
#   Winner (WTA): 2
#   Distances: [5.78702477 5.7782075  0.14223833]
#   Winner (WTA): 2
#   Distances: [7.42841024 6.23353097 1.77616199]
#   Winner (WTA): 2
#   Distances: [5.25566864 6.03201588 0.60377601]
#   Winner (WTA): 2
#   Distances: [5.80383411 4.44919664 1.5361011 ]
#   Winner (WTA): 2
#   Distances: [6.27089953 6.69353201 0.8312886 ]
#   Winner (WTA): 2
#   Distances: [5.00373849 4.89815664 1.08916764]
#   Winner (WTA): 2
#   Distances: [5.22862259 6.34062697 0.88472224]
#   Winner (WTA): 2
#   Distances: [4.57289454 5.73358604 1.19069275]
#   Winner (WTA): 2
#   Distances: [6.06930252 6.56428239 0.68326613]
#   Winner (WTA): 2
#   Distances: [7.03830328 6.50393657 1.30007158]
#   Winner (WTA): 2
#   Distances: [5.19196857 5.51955242 0.5763295 ]
#   Winner (WTA): 2
#   Distances: [5.74723704 5.85102976 0.03829909]
#   Winner (WTA): 2
#   Distances: [5.56628221 1.22929756 4.68066828]
#   Winner (WTA): 1
#   Distances: [6.5001894  0.33208332 5.70034289]
#   Winner (WTA): 1
#   Distances: [5.73913337 0.91230077 6.08620384]
#   Winner (WTA): 1
#   Distances: [7.50200365 2.18466632 8.03539249]
#   Winner (WTA): 1
#   Distances: [6.37162224 0.6223937  6.38833638]
#   Winner (WTA): 1
#   Distances: [4.96877328 1.7953232  4.27783372]
#   Winner (WTA): 1
#   Distances: [4.8084435  2.98151502 7.1133763 ]
#   Winner (WTA): 1
#   Distances: [5.78633988 0.80937736 6.02965313]
#   Winner (WTA): 1
#   Distances: [6.97868814 0.67866431 5.99353439]
#   Winner (WTA): 1
#   Distances: [6.56426326 1.83335415 7.43587397]
#   Winner (WTA): 1
#   Distances: [7.33596675 1.05926671 6.82596081]
#   Winner (WTA): 1
#   Distances: [8.11711999 1.82582307 7.43319541]
#   Winner (WTA): 1
#   Distances: [5.39941021 2.80765505 7.44025486]
#   Winner (WTA): 1
#   Distances: [5.92311271 0.80349854 5.07918147]
#   Winner (WTA): 1
#   Distances: [6.56343653 0.2888524  6.1689386 ]
#   Winner (WTA): 1
#   Distances: [5.0826208  1.47847577 4.65787619]
#   Winner (WTA): 1
#   Distances: [5.05906519 1.31359929 5.24515465]
#   Winner (WTA): 1
#   Distances: [4.41828983 2.18349313 5.80909339]
#   Winner (WTA): 1
#   Distances: [5.85029674 0.62245045 5.32035568]
#   Winner (WTA): 1
#   Distances: [7.58237491 1.2361901  6.84159821]
#   Winner (WTA): 1
#   Distances: [5.49401738 1.86217142 6.74500306]
#   Winner (WTA): 1
#   Distances: [4.95464077 1.57832656 4.63700068]
#   Winner (WTA): 1
#   Distances: [5.82136938 1.3655897  6.59752853]
#   Winner (WTA): 1
#   Distances: [6.43064586 1.32597895 4.79226343]
#   Winner (WTA): 1
#   Distances: [6.32655351 1.07396173 6.72235353]
#   Winner (WTA): 1
#   Distances: [6.0860683  0.96077181 6.46991562]
#   Winner (WTA): 1
#   Distances: [5.49382104 0.88806228 5.54052127]
#   Winner (WTA): 1
#   Distances: [6.84956711 0.52460448 6.34096719]
#   Winner (WTA): 1
#   Distances: [7.32490568 2.27737563 8.07256891]
#   Winner (WTA): 1
#   Distances: [4.83645956 1.53624526 5.18639169]
#   Winner (WTA): 1
#   Distances: [4.88816658 1.51453584 5.43569937]
#   Winner (WTA): 1
#   Distances: [7.53968331 1.38359965 7.19749365]
#   Winner (WTA): 1
#   Distances: [6.60657965 1.47508359 7.17853585]
#   Winner (WTA): 1
#   Distances: [5.73288972 2.60859436 7.52397989]
#   Winner (WTA): 1
#   Distances: [6.52367529 0.252257   5.80107912]
#   Winner (WTA): 1
#   Distances: [6.18571303 0.76507543 5.1540666 ]
#   Winner (WTA): 1
#   Distances: [5.843697   0.85634027 6.15117615]
#   Winner (WTA): 1
#   Distances: [5.80769064 1.41395485 6.62738959]
#   Winner (WTA): 1
#   Distances: [5.23445305 1.97174978 6.60438996]
#   Winner (WTA): 1
#   Distances: [4.41195245 3.22887544 6.97896717]
#   Winner (WTA): 1
#   Distances: [7.18264658 0.88656149 6.66337091]
#   Winner (WTA): 1
#   Distances: [5.04672719 1.32594268 5.23989481]
#   Winner (WTA): 1
#   Distances: [5.48693857 1.22230542 6.11687692]
#   Winner (WTA): 1
#   Distances: [6.52953983 0.79246584 6.60094756]
#   Winner (WTA): 1
#   Distances: [6.79577966 1.20273335 5.18991278]
#   Winner (WTA): 1
#   Distances: [5.22503711 1.38828325 5.95367593]
#   Winner (WTA): 1
#   Distances: [7.19566683 0.84091552 6.24223085]
#   Winner (WTA): 1
#   Distances: [6.00200467 0.96384542 6.40452193]
#   Winner (WTA): 1
#   Distances: [5.41790243 0.95929132 5.32329852]
#   Winner (WTA): 1
#   Distances: [7.01715354 0.68162054 6.08670395]
#   Winner (WTA): 1
#   Distances: [0.37432397 6.74688027 5.94016053]
#   Winner (WTA): 0
#   Distances: [0.90354958 6.69537365 6.61516209]
#   Winner (WTA): 0
#   Distances: [2.33308999 7.14439892 4.29189099]
#   Winner (WTA): 0
#   Distances: [0.24852653 6.60836066 5.93340858]
#   Winner (WTA): 0
#   Distances: [3.56992767 9.3996087  9.19854169]
#   Winner (WTA): 0
#   Distances: [0.85239394 7.05867868 6.54920581]
#   Winner (WTA): 0
#   Distances: [0.50334789 6.4414778  6.19261245]
#   Winner (WTA): 0
#   Distances: [1.03990932 7.34955908 6.01679326]
#   Winner (WTA): 0
#   Distances: [1.47754987 7.02984418 4.98517309]
#   Winner (WTA): 0
#   Distances: [1.1137364  7.00821022 5.32505419]
#   Winner (WTA): 0
#   Distances: [2.74490999 3.63365238 4.73118968]
#   Winner (WTA): 0
#   Distances: [1.89831691 5.03922013 3.98981499]
#   Winner (WTA): 0
#   Distances: [1.34838082 7.69619865 6.32888552]
#   Winner (WTA): 0
#   Distances: [1.46703288 5.8562099  4.27946808]
#   Winner (WTA): 0
#   Distances: [1.38293998 7.57941383 5.90334197]
#   Winner (WTA): 0
#   Distances: [1.34193688 7.28173896 5.44006351]
#   Winner (WTA): 0
#   Distances: [1.09265482 6.13010279 4.68843764]
#   Winner (WTA): 0
#   Distances: [1.57346555 5.7922196  6.65408073]
#   Winner (WTA): 0
#   Distances: [2.6368161  8.29257443 5.49315693]
#   Winner (WTA): 0
#   Distances: [1.39289095 7.66041156 6.07893148]
#   Winner (WTA): 0
#   Distances: [1.45798851 7.12016673 5.10615252]
#   Winner (WTA): 0
#   Distances: [0.59107116 6.88590201 6.27147053]
#   Winner (WTA): 0
#   Distances: [1.91293254 7.31780579 4.88398995]
#   Winner (WTA): 0
#   Distances: [1.43370876 6.54190846 4.59553223]
#   Winner (WTA): 0
#   Distances: [1.16189709 5.78013677 6.27638691]
#   Winner (WTA): 0
#   Distances: [1.97519801 8.14271428 6.13773265]
#   Winner (WTA): 0
#   Distances: [1.687343   6.15822847 6.99716887]
#   Winner (WTA): 0
#   Distances: [2.26360944 7.50071508 4.75666037]
#   Winner (WTA): 0
#   Distances: [1.18963934 5.19620488 5.05836189]
#   Winner (WTA): 0
#   Distances: [0.51791048 6.85384245 6.16827261]
#   Winner (WTA): 0
#   Distances: [1.57473723 7.26011522 5.15691977]
#   Winner (WTA): 0
#   Distances: [4.06734235 8.77329047 4.73954666]
#   Winner (WTA): 0
#   Distances: [1.75793817 6.0221161  4.04274658]
#   Winner (WTA): 0
#   Distances: [1.99602001 4.42430613 4.626739  ]
#   Winner (WTA): 0
#   Distances: [1.06104685 7.00628142 5.37843436]
#   Winner (WTA): 0
#   Distances: [1.91033532 4.55970084 4.51474635]
#   Winner (WTA): 0
#   Distances: [0.61735005 5.80674767 5.66650475]
#   Winner (WTA): 0
#   Distances: [1.60130336 7.63225936 5.67774771]
#   Winner (WTA): 0
#   Distances: [0.97504532 6.04465319 4.77558787]
#   Winner (WTA): 0
#   Distances: [0.8600783  6.28271052 4.9533382 ]
#   Winner (WTA): 0
#   Distances: [0.62393687 6.98521228 5.98742025]
#   Winner (WTA): 0
#   Distances: [1.80803342 4.59264464 4.75972894]
#   Winner (WTA): 0
#   Distances: [2.70562554 3.70167394 4.54335659]
#   Winner (WTA): 0
#   Distances: [0.8201727  7.11324242 5.86954998]
#   Winner (WTA): 0
#   Distances: [0.96456057 5.96771639 4.77566898]
#   Winner (WTA): 0
#   Distances: [1.12824375 6.42718451 4.79310555]
#   Winner (WTA): 0
#   Distances: [1.32589186 7.60684778 6.08090079]
#   Winner (WTA): 0
#   Distances: [1.00916275 5.86430291 4.72988862]
#   Winner (WTA): 0
#   Distances: [0.29066388 6.20347855 5.84950306]
#   Winner (WTA): 0
#   Distances: [0.40077786 6.50977569 6.12813133]
#   Winner (WTA): 0

# %%
from PIL import Image
import numpy as np

# %%
image_path = "C:/Users/prath/Downloads/d1.jpg"
image = Image.open(image_path)

# %%
image = image.resize((100,100))

# %%
img_data = np.array(image)

# %%
pixels = img_data.reshape((-1,3))

# %%
pixels = pixels/255.0

# %%
from minisom import MiniSom

som_size = 10
input_len = 3
sigma = 1.0
learning_rate = 0.5
itertions = 1000

som = MiniSom(som_size,som_size,input_len,sigma=sigma,learning_rate = learning_rate)

som.train(pixels,itertions)

# %%
quantize_pixels = np.array([som.winner(p) for p in pixels])
